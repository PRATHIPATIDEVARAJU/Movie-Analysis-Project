# %%
# import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\IMDb_Dataset.csv")

# %%
# dataset to load

data
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 395                            Mother of the Bride          4.8  2024
# 396                        Beetlejuice Beetlejuice          7.1  2024
# 397                                The Idea of You          6.4  2024
# 398                                             IF          6.7  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
# top 5 rows

data.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
# last 5 rows

data.tail(10)
# Out:
#                        Title  IMDb Rating  Year Certificates      Genre  \
# 390             Emilia Perez          7.2  2024            R     Comedy
# 391           Anyone But You          6.1  2023            R     Comedy
# 392     Deadpool & Wolverine          7.1  2024            R     Action
# 393       The Garfield Movie          5.9  2024           PG  Animation
# 394        Kinds of Kindness          7.0  2024            R     Comedy
# 395      Mother of the Bride          4.8  2024        TV-PG     Comedy
# 396  Beetlejuice Beetlejuice          7.1  2024            R     Comedy
# 397          The Idea of You          6.4  2024            R     Comedy
# 398                       IF          6.7  2024           PG  Animation
# 399             The Fall Guy          7.1  2024        PG-13     Action
#
#               Director                                       Star Cast  \
# 390    Jacques Audiard  Jacques AudiardThomas BidegainNicolas Livecchi
# ...

# %%
#No. of rows and columns 

data.shape
# Out:
# (400, 9)

# %%
data.shape[0] # Get the number of rows only
# Out:
# 400

# %%
data.shape[1] # Get the number of columns only
# Out:
# 9

# %%
list(data.columns)
# Out:
# ['Title',
#  'IMDb Rating',
#  'Year',
#  'Certificates',
#  'Genre',
#  'Director',
#  'Star Cast',
#  'MetaScore',
#  'Duration (minutes)']

# %%
#To find complete information

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               400 non-null    object
#  1   IMDb Rating         400 non-null    float64
#  2   Year                400 non-null    int64
#  3   Certificates        400 non-null    object
#  4   Genre               400 non-null    object
#  5   Director            400 non-null    object
#  6   Star Cast           400 non-null    object
#  7   MetaScore           400 non-null    float64
#  8   Duration (minutes)  400 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
# statistical description of numeric columns

data.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   400.000000   400.000000  400.000000          400.000000
# mean      7.110250  2015.150000   66.898750          116.334750
# std       0.932251    13.470194   15.312006           21.369757
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2010.750000   57.750000          101.000000
# 50%       7.100000  2023.000000   66.900000          116.000000
# 75%       7.700000  2024.000000   77.000000          124.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
#to find null values

data.isnull()
# Out:
#      Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0    False        False  False         False  False     False      False
# 1    False        False  False         False  False     False      False
# 2    False        False  False         False  False     False      False
# 3    False        False  False         False  False     False      False
# 4    False        False  False         False  False     False      False
# ..     ...          ...    ...           ...    ...       ...        ...
# 395  False        False  False         False  False     False      False
# 396  False        False  False         False  False     False      False
# 397  False        False  False         False  False     False      False
# 398  False        False  False         False  False     False      False
# 399  False        False  False         False  False     False      False
#
#      MetaScore  Duration (minutes)
# 0        False               False
# ...

# %%
data.isnull().head(10)
# Out:
#    Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0  False        False  False         False  False     False      False
# 1  False        False  False         False  False     False      False
# 2  False        False  False         False  False     False      False
# 3  False        False  False         False  False     False      False
# 4  False        False  False         False  False     False      False
# 5  False        False  False         False  False     False      False
# 6  False        False  False         False  False     False      False
# 7  False        False  False         False  False     False      False
# 8  False        False  False         False  False     False      False
# 9  False        False  False         False  False     False      False
#
#    MetaScore  Duration (minutes)
# 0      False               False
# 1      False               False
# 2      False               False
# 3      False               False
# ...

# %%
#sum of null values

#data.isnull().sum()
data.isna().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
# count of Year

data["Year"].value_counts()
# Out:
# Year
# 2024    143
# 2023     63
# 2022     18
# 2018     12
# 2001     11
# 2019     10
# 2015      9
# 2021      9
# 2017      8
# 2014      8
# 2016      8
# 2004      7
# 1994      6
# 2007      6
# 2013      6
# 1999      5
# 2008      5
# 1979      5
# 1984      5
# 1995      4
# 2010      4
# 1981      3
# 2005      3
# 2006      3
# 1993      3
# 2003      3
# 1997      3
# 2011      3
# 1985      3
# 2002      3
# 1996      2
# 1968      2
# 2009      2
# 2012      2
# 1987      1
# 1939      1
# 1971      1
# 2025      1
# 2000      1
# 1972      1
# 1990      1
# 1983      1
# 1991      1
# 1957      1
# 1976      1
# 1986      1
# 1988      1
# Name: count, dtype: int64

# %%
# count of IMDb Ratings
data["IMDb Rating"].value_counts()
# Out:
# IMDb Rating
# 7.1    59
# 7.0    24
# 7.6    21
# 6.7    18
# 7.2    16
# 6.8    16
# 7.4    14
# 8.0    13
# 7.9    13
# 7.5    13
# 8.1    12
# 8.2    12
# 7.3    11
# 6.5    11
# 5.6    10
# 6.2    10
# 5.7    10
# 8.4    10
# 8.6     9
# 6.3     9
# 7.7     8
# 7.8     8
# 8.5     8
# 6.1     6
# 5.8     5
# 5.9     5
# 6.9     5
# 6.0     5
# 8.7     4
# 5.5     4
# 6.4     4
# 5.0     4
# 3.9     3
# 8.3     3
# 5.2     3
# 5.3     2
# 9.0     2
# 8.8     2
# 8.9     2
# 6.6     1
# 4.6     1
# 9.2     1
# 4.9     1
# 4.4     1
# 4.8     1
# Name: count, dtype: int64

# %%
data[["Genre","Director"]].head()
# Out:
#        Genre               Director
# 0     Action           Ridley Scott
# 1     Action  Christopher McQuarrie
# 2     Action            Zack Snyder
# 3  Adventure      Quentin Tarantino
# 4     Action               Eli Roth

# %%
#only columns

data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')

# %%
# only specific row

data[data.index == 2]
# Out:
#                                   Title  IMDb Rating  Year Certificates  \
# 2  Rebel Moon - Part Two: The Scargiver          5.2  2024        PG-13
#
#     Genre     Director                            Star Cast  MetaScore  \
# 2  Action  Zack Snyder  Zack SnyderKurt JohnstadShay Hatten       35.0
#
#    Duration (minutes)
# 2               122.0

# %%
#Isolating two or more rows using [ ] 
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
data[data.index.isin(range(2,10))]
# Out:
#                                   Title  IMDb Rating  Year Certificates  \
# 2  Rebel Moon - Part Two: The Scargiver          5.2  2024        PG-13
# 3                  Inglourious Basterds          8.4  2009            R
# 4                           Borderlands          7.1  2024            R
# 5                         Jurassic Park          8.2  1993        PG-13
# 6                     The Fifth Element          7.6  1997        PG-13
# 7                            Inside Out          8.1  2015           PG
# 8          Descendants: The Rise of Red          7.1  2024         TV-G
# 9                                  Wish          5.6  2023           PG
#
#        Genre           Director                                Star Cast  \
# 2     Action        Zack Snyder      Zack SnyderKurt JohnstadShay Hatten
# 3  Adventure  Quentin Tarantino            Brad PittDiane KrugerEli Roth
# 4     Action           Eli Roth                      Eli RothJoe Crombie
# ...

# %%
data.loc[2:10]
# Out:
#                                    Title  IMDb Rating  Year Certificates  \
# 2   Rebel Moon - Part Two: The Scargiver          5.2  2024        PG-13
# 3                   Inglourious Basterds          8.4  2009            R
# 4                            Borderlands          7.1  2024            R
# 5                          Jurassic Park          8.2  1993        PG-13
# 6                      The Fifth Element          7.6  1997        PG-13
# 7                             Inside Out          8.1  2015           PG
# 8           Descendants: The Rise of Red          7.1  2024         TV-G
# 9                                   Wish          5.6  2023           PG
# 10                      The Hunger Games          7.2  2012        PG-13
#
#         Genre           Director                                Star Cast  \
# 2      Action        Zack Snyder      Zack SnyderKurt JohnstadShay Hatten
# 3   Adventure  Quentin Tarantino            Brad PittDiane KrugerEli Roth
# ...

# %%
data.iloc[2:10]
# Out:
#                                   Title  IMDb Rating  Year Certificates  \
# 2  Rebel Moon - Part Two: The Scargiver          5.2  2024        PG-13
# 3                  Inglourious Basterds          8.4  2009            R
# 4                           Borderlands          7.1  2024            R
# 5                         Jurassic Park          8.2  1993        PG-13
# 6                     The Fifth Element          7.6  1997        PG-13
# 7                            Inside Out          8.1  2015           PG
# 8          Descendants: The Rise of Red          7.1  2024         TV-G
# 9                                  Wish          5.6  2023           PG
#
#        Genre           Director                                Star Cast  \
# 2     Action        Zack Snyder      Zack SnyderKurt JohnstadShay Hatten
# 3  Adventure  Quentin Tarantino            Brad PittDiane KrugerEli Roth
# 4     Action           Eli Roth                      Eli RothJoe Crombie
# ...

# %%
# give me top 5 MetaScore

data.nlargest(5, 'MetaScore')
# Out:
#              Title  IMDb Rating  Year Certificates      Genre  \
# 137  The Godfather          9.2  1972            R      Crime
# 106   12 Angry Men          9.0  1957     Approved      Crime
# 58       Toy Story          8.3  1995            G  Animation
# 75     Ratatouille          8.1  2007            G  Animation
# 86   Spirited Away          8.6  2001           PG  Animation
#
#                  Director                               Star Cast  MetaScore  \
# 137  Francis Ford Coppola          Mario PuzoFrancis Ford Coppola      100.0
# 106          Sidney Lumet                           Reginald Rose       97.0
# 58          John Lasseter  John LasseterPete DocterAndrew Stanton       96.0
# 75              Brad Bird      Brad BirdJan PinkavaJim Capobianco       96.0
# 86         Hayao Miyazaki                          Hayao Miyazaki       96.0
#
#      Duration (minutes)
# 137               175.0
# 106                96.0
# 58                 81.0
# 75                111.0
# ...

# %%
#give me below 5 MetaScore

data.nsmallest(5, 'MetaScore')
# Out:
#                                       Title  IMDb Rating  Year Certificates  \
# 43                               Madame Web          3.9  2024        PG-13
# 243                              Madame Web          3.9  2024        PG-13
# 345                              Madame Web          3.9  2024        PG-13
# 271                     Garfield: The Movie          5.0  2004           PG
# 11   Rebel Moon - Part One: A Child of Fire          5.6  2023        PG-13
#
#          Genre       Director  \
# 43      Action  S.J. Clarkson
# 243     Action  S.J. Clarkson
# 345     Action  S.J. Clarkson
# 271  Adventure   Peter Hewitt
# 11      Action    Zack Snyder
#
#                                              Star Cast  MetaScore  \
# 43              Matt SazamaBurk SharplessClaire Parker       26.0
# 243             Matt SazamaBurk SharplessClaire Parker       26.0
# 345             Matt SazamaBurk SharplessClaire Parker       26.0
# ...

# %%
# top 5 Years

data.nlargest(5,  'Year')
# Out:
#                                     Title  IMDb Rating  Year Certificates  \
# 256                             Minecraft          7.1  2025            R
# 2    Rebel Moon - Part Two: The Scargiver          5.2  2024        PG-13
# 4                             Borderlands          7.1  2024            R
# 8            Descendants: The Rise of Red          7.1  2024         TV-G
# 17                                 Damsel          6.1  2024        PG-13
#
#       Genre                 Director  \
# 256  Action               Jared Hess
# 2    Action              Zack Snyder
# 4    Action                 Eli Roth
# 8    Action           Jennifer Phang
# 17   Action  Juan Carlos Fresnadillo
#
#                                         Star Cast  MetaScore  \
# 256    Chris BowmanHubbel PalmerAllison Schroeder       66.9
# 2             Zack SnyderKurt JohnstadShay Hatten       35.0
# 4                             Eli RothJoe Crombie       66.9
# ...

# %%
# give me below 5 Years

data.nsmallest(5, 'Year')
# Out:
#                                    Title  IMDb Rating  Year Certificates  \
# 266                     The Wizard of Oz          8.1  1939            G
# 106                         12 Angry Men          9.0  1957     Approved
# 25                    Planet of the Apes          8.0  1968            G
# 227                   Planet of the Apes          8.0  1968            G
# 257  Willy Wonka & the Chocolate Factory          7.8  1971            G
#
#          Genre               Director  \
# 266  Adventure         Victor Fleming
# 106      Crime           Sidney Lumet
# 25   Adventure  Franklin J. Schaffner
# 227  Adventure  Franklin J. Schaffner
# 257  Adventure             Mel Stuart
#
#                                          Star Cast  MetaScore  \
# 266  Noel LangleyFlorence RyersonEdgar Allan Woolf       92.0
# 106                                  Reginald Rose       97.0
# 25          Michael WilsonRod SerlingPierre Boulle       79.0
# ...

# %% [markdown]
# ## Dealing with missing data technique

# %%
data1 = data.dropna()

# %%
# finding the null values after the dropna() method
data1.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\IMDb_Dataset.csv",usecols = ['Certificates','Director','MetaScore'])

# %%
data.dropna(inplace=True, axis=0)
print(data.head())
print(data.isnull().sum())
# Out:
#   Certificates               Director  MetaScore
# 0            R           Ridley Scott       67.0
# 1        PG-13  Christopher McQuarrie       81.0
# 2        PG-13            Zack Snyder       35.0
# 3            R      Quentin Tarantino       69.0
# 4            R               Eli Roth       66.9
# Certificates    0
# Director        0
# MetaScore       0
# dtype: int64

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\IMDb_Dataset.csv")

data['Certificates'] = data['Certificates'].fillna(333)
data
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 395                            Mother of the Bride          4.8  2024
# 396                        Beetlejuice Beetlejuice          7.1  2024
# 397                                The Idea of You          6.4  2024
# 398                                             IF          6.7  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
data.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
mean_value = data['MetaScore'].mean()
print(mean_value)
# Out:
# 66.89875

# %%
data3 = data.fillna(mean_value)

# %%
data3.head(12)
# Out:
#                                             Title  IMDb Rating  Year  \
# 0                                       Gladiator          8.5  2000
# 1   Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2            Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                            Inglourious Basterds          8.4  2009
# 4                                     Borderlands          7.1  2024
# 5                                   Jurassic Park          8.2  1993
# 6                               The Fifth Element          7.6  1997
# 7                                      Inside Out          8.1  2015
# 8                    Descendants: The Rise of Red          7.1  2024
# 9                                            Wish          5.6  2023
# 10                               The Hunger Games          7.2  2012
# 11         Rebel Moon - Part One: A Child of Fire          5.6  2023
#
#    Certificates      Genre               Director  \
# ...

# %%
#replacing the NAN value usinf median()
median_value =data['MetaScore'].median()
data4 = data.fillna(median_value)
print(median_value)
# Out:
# 66.9

# %%
data4.head(12)
# Out:
#                                             Title  IMDb Rating  Year  \
# 0                                       Gladiator          8.5  2000
# 1   Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2            Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                            Inglourious Basterds          8.4  2009
# 4                                     Borderlands          7.1  2024
# 5                                   Jurassic Park          8.2  1993
# 6                               The Fifth Element          7.6  1997
# 7                                      Inside Out          8.1  2015
# 8                    Descendants: The Rise of Red          7.1  2024
# 9                                            Wish          5.6  2023
# 10                               The Hunger Games          7.2  2012
# 11         Rebel Moon - Part One: A Child of Fire          5.6  2023
#
#    Certificates      Genre               Director  \
# ...

# %%
#replacing the NAN value usinf mode()
mode_value =data['MetaScore'].mode()[0]
data5 = data.fillna(mode_value)
print(mode_value)
# Out:
# 66.9

# %%
data5.head(12)
# Out:
#                                             Title  IMDb Rating  Year  \
# 0                                       Gladiator          8.5  2000
# 1   Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2            Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                            Inglourious Basterds          8.4  2009
# 4                                     Borderlands          7.1  2024
# 5                                   Jurassic Park          8.2  1993
# 6                               The Fifth Element          7.6  1997
# 7                                      Inside Out          8.1  2015
# 8                    Descendants: The Rise of Red          7.1  2024
# 9                                            Wish          5.6  2023
# 10                               The Hunger Games          7.2  2012
# 11         Rebel Moon - Part One: A Child of Fire          5.6  2023
#
#    Certificates      Genre               Director  \
# ...

# %%
data.shape
# Out:
# (400, 9)

# %%
data5 = data.drop_duplicates()
data5.shape
# Out:
# (255, 9)

# %% [markdown]
# ## Data Visualization

# %%
data.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
df = pd.read_csv(r"C:\Users\devad\Downloads\IMDb_Dataset.csv")

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['IMDb Rating'], bins=20, edgecolor='r')
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['IMDb Rating'], df['MetaScore'], alpha=0.5)
plt.title('IMDb Rating vs. MetaScore')
plt.xlabel('IMDb Rating')
plt.ylabel('MetaScore')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Duration (minutes)'], df['IMDb Rating'], color='darkblue', alpha=0.6)
plt.xlabel('Duration (minutes)')
plt.ylabel('IMDb Rating')
plt.title('IMDb Rating vs Duration')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['MetaScore'], bins=20, color='purple', edgecolor='black')
plt.xlabel('MetaScore')
plt.ylabel('Frequency')
plt.title('Distribution of MetaScores')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['Year'], df['IMDb Rating'], color='skyblue')
plt.xlabel('Year')
plt.ylabel('IMDb Rating')
plt.title('IMDb Ratings by Year')
plt.show()

# %%
genre_counts = df['Genre'].value_counts()

plt.figure(figsize=(12, 6))
plt.bar(genre_counts.index, genre_counts, color='seagreen')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.title('Count of Movies by Genre')
plt.show()

# %%
# Calculate average IMDb Rating per Genre
genre_ratings = df.groupby('Genre')['IMDb Rating'].mean().sort_values()

plt.figure(figsize=(12, 8))
genre_ratings.plot(kind='barh', color='skyblue')
plt.title('Average IMDb Rating by Genre')
plt.xlabel('Average IMDb Rating')
plt.ylabel('Genre')
plt.show()

# %%
# Calculate average IMDb Rating per Year
year_ratings = df.groupby('Year')['IMDb Rating'].mean()

plt.figure(figsize=(12, 6))
year_ratings.plot(kind='line', marker='D', color='purple')
plt.title('Average IMDb Rating Over Years')
plt.xlabel('Year')
plt.ylabel('Average IMDb Rating')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df.boxplot(column='IMDb Rating', by='Certificates')
plt.title('IMDb Rating by Certificate')
plt.xlabel('Certificates')
plt.ylabel('IMDb Rating')
plt.show()

# %%
# Calculate genre distribution
genre_counts = df['Genre'].value_counts()

plt.figure(figsize=(10, 8))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired(range(len(genre_counts))))
plt.title('Genre Distribution')
plt.show()

# %%
Certificates_counts = df['Certificates'].value_counts()

plt.figure(figsize=(12, 8))
plt.pie(Certificates_counts, labels=Certificates_counts.index, autopct='%1.1f%%', startangle=120)

plt.title('Distribution of Certificates')
plt.show()

# %%
plt.figure(figsize=(12, 8))
df.boxplot(column='Duration (minutes)', by='Genre')
plt.title('Duration by Genre')
plt.xlabel('Genre')
plt.ylabel('Duration (minutes)')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Duration (minutes)'], df['IMDb Rating'], alpha=0.5, color='green')
plt.title('Duration vs. IMDb Rating')
plt.xlabel('Duration (minutes)')
plt.ylabel('IMDb Rating')
plt.grid(True)
plt.show()

# %%
# Calculate average MetaScore per Year
year_metacore = df.groupby('Year')['MetaScore'].mean()

plt.figure(figsize=(12, 6))
year_metacore.plot(kind='line', marker='o', color='orange')
plt.title('Average MetaScore Over Years')
plt.xlabel('Year')
plt.ylabel('Average MetaScore')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(14, 8))
for director in df['Director'].value_counts().index[:10]:
    plt.hist(df[df['Director'] == director]['IMDb Rating'], bins=20, alpha=0.5, label=director)

plt.legend()
plt.show()

# %%
df = pd.read_csv(r"C:\Users\devad\Downloads\IMDb_Dataset.csv")

# %%
df.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Genre', y='IMDb Rating', data=df)
plt.title('Average IMDb Rating by Genre')
plt.xlabel('Genre')
plt.ylabel('IMDb Rating')
plt.show()

# %%
sns.barplot(x='IMDb Rating', y='Title', data=top_10_movies, hue='Title', palette='coolwarm')
plt.title('Top 10 Movies with the Highest IMDb Ratings')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['IMDb Rating'], bins=20, kde=True)
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Genre', y='IMDb Rating', data=df)
plt.title('IMDb Ratings by Genre')
plt.xlabel('Genre')
plt.ylabel('IMDb Rating')
plt.show()

# %%
sns.boxplot(x='Certificates', y='IMDb Rating', data=df, hue='Certificates', palette='Set2')
plt.xticks(rotation=45)
plt.title('IMDb Ratings by Certificates')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Year', y='IMDb Rating', data=df)
plt.title('IMDb Ratings by Year')
plt.xlabel('Year')
plt.ylabel('IMDb Rating')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.regplot(x='MetaScore', y='IMDb Rating', data=df, scatter_kws={'s':50}, line_kws={'color':'red'})
plt.title('MetaScore vs. IMDb Rating')
plt.xlabel('MetaScore')
plt.ylabel('IMDb Rating')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='MetaScore', y='IMDb Rating', data=df)
plt.title('MetaScore vs IMDb Rating')
plt.xlabel('MetaScore')
plt.ylabel('IMDb Rating')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='Year', y='IMDb Rating', data=df, color = 'g', ms = 10)
plt.title('Average IMDb Rating Over the Years')
plt.xlabel('Year')
plt.ylabel('Average IMDb Rating')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['MetaScore'], bins=20, kde=True, color='purple')
plt.title('Distribution of MetaScore')
plt.xlabel('MetaScore')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='Director', data=df[df['Director'].isin(df['Director'].value_counts().index[:10])])
plt.title('Number of Movies by Top 10 Directors')
plt.show()

# %%
sns.countplot(y='Genre', data=df, order=df['Genre'].value_counts().index, hue='Genre', palette='pastel', dodge=False)
plt.title('Distribution of Genres')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Duration (minutes)', y='IMDb Rating', data=df, hue='Genre', palette='viridis')
plt.title('Duration vs IMDb Rating')
plt.xlabel('Duration (minutes)')
plt.ylabel('IMDb Rating')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Duration (minutes)', y='IMDb Rating', data=df, hue='Genre')
plt.title('IMDb Rating vs Duration (minutes)')
plt.show()

# %%
heatmap_data = df.pivot_table(index='Year', columns='Genre', values='IMDb Rating', aggfunc='mean')

plt.figure(figsize=(14, 10))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='.1f', linewidths=.5)
plt.title('Average IMDb Rating by Year and Genre')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df[['MetaScore', 'IMDb Rating']].corr(), annot=True, cmap='viridis')
plt.title('Correlation Heatmap: MetaScore vs IMDb Rating')
plt.show()

# %%
genre_duration = df.pivot_table(index='Genre', values='Duration (minutes)', aggfunc='mean')#aggregation function

plt.figure(figsize=(12, 6))
sns.heatmap(genre_duration, annot=True, cmap='Greens')
plt.title('Average Duration by Genre')
plt.ylabel('Genre')
plt.xlabel('Average Duration (minutes)')
plt.show()

# %%
director_rating = df.pivot_table(index='Director', values='IMDb Rating', aggfunc='mean')#aggregation function

plt.figure(figsize=(12, 8))
sns.heatmap(director_rating, annot=True, cmap='Reds')
plt.title('Average IMDb Rating by Director')
plt.xlabel('Average IMDb Rating')
plt.ylabel('Director')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df[['IMDb Rating', 'MetaScore', 'Duration (minutes)']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
sns.pairplot(df[['IMDb Rating', 'MetaScore', 'Duration (minutes)']])
plt.suptitle('Pairplot of IMDb Rating, MetaScore, and Duration', y=1.02)
plt.show()

# %%
numerical_columns = ['IMDb Rating', 'Year', 'MetaScore', 'Duration (minutes)']

sns.pairplot(df[numerical_columns], diag_kind='kde')
plt.suptitle('Pair Plot of Selected Numerical Variables', y=1.02)
plt.show()
